# %%
# !pip install lazypredict

# %%
from lazypredict.Supervised import LazyRegressor, LazyClassifier
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# read the data
data = pd.read_csv("final_data.csv")

# Creating train test split
y = data['Target']
X = data.drop(columns=['Target'], axis=1)

# Call train_test_split on the data and capture the results
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
reg = LazyRegressor(ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
#  21%|██▏       | 9/42 [00:01<00:06,  4.80it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range for family GammaDistribution
# 100%|██████████| 42/42 [00:14<00:00,  2.92it/s]

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.89       0.89  0.10        0.14
# HistGradientBoostingRegressor                0.89       0.89  0.10        0.94
# RandomForestRegressor                        0.88       0.88  0.10        0.78
# BayesianRidge                                0.88       0.88  0.10        0.04
# RidgeCV                                      0.88       0.88  0.10        0.04
# Ridge                                        0.88       0.88  0.10        0.02
# Lars                                         0.88       0.88  0.10        0.04
# LinearRegression                             0.88       0.88  0.10        0.03
# TransformedTargetRegressor                   0.88       0.88  0.10        0.03
# ElasticNetCV                                 0.88       0.88  0.10        0.18
# OrthogonalMatchingPursuitCV                  0.88       0.88  0.10        0.05
# LassoCV                                      0.88       0.88  0.10        0.24
# LarsCV                                       0.88       0.88  0.10        0.11
# LassoLarsCV                                  0.88       0.88  0.10        0.12
# LassoLarsIC                                  0.88       0.88  0.10        0.04
# SGDRegressor                                 0.87       0.88  0.11        0.03
# GradientBoostingRegressor                    0.87       0.88  0.11        0.34
# BaggingRegressor                             0.87       0.87  0.11        0.10
# XGBRegressor                                 0.86       0.87  0.11        0.51
# ExtraTreesRegressor                          0.86       0.86  0.11        0.84
# GeneralizedLinearRegressor                   0.84       0.84  0.12        0.03
# TweedieRegressor                             0.84       0.84  0.12        0.03
# HuberRegressor                               0.83       0.84  0.12        0.30
# OrthogonalMatchingPursuit                    0.82       0.83  0.12        0.03
# MLPRegressor                                 0.82       0.83  0.13        1.01
# DecisionTreeRegressor                        0.82       0.83  0.13        0.08
# AdaBoostRegressor                            0.81       0.82  0.13        0.15
# LinearSVR                                    0.80       0.81  0.13        0.47
# RANSACRegressor                              0.79       0.80  0.14        0.20
# PassiveAggressiveRegressor                   0.79       0.80  0.14        0.03
# KNeighborsRegressor                          0.78       0.79  0.14        0.18
# ExtraTreeRegressor                           0.76       0.77  0.15        0.05
# NuSVR                                        0.74       0.75  0.15        3.77
# SVR                                          0.74       0.75  0.15        0.39
# PoissonRegressor                             0.68       0.69  0.17        0.04
# Lasso                                       -0.04      -0.01  0.30        0.03
# ElasticNet                                  -0.04      -0.01  0.30        0.02
# DummyRegressor                              -0.04      -0.01  0.30        0.03
# LassoLars                                   -0.04      -0.01  0.30        0.05
# GaussianProcessRegressor                    -0.41      -0.36  0.35        1.96
# KernelRidge                                 -0.56      -0.51  0.37        0.86
