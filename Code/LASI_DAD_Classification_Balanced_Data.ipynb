# %%
# !pip install lazypredict

# %%
from lazypredict.Supervised import LazyRegressor, LazyClassifier
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# read the data
data = pd.read_csv("up_sampled_data.csv")

# Creating train test split
y = data['Target'].astype(str)
X = data.drop(columns=['Target'], axis=1)

#Call train_test_split on the data and capture the results
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

# %%
classi=LazyClassifier(verbose=0,predictions=True)
models_c,predictions_c=classi.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 29/29 [00:55<00:00,  1.92s/it]

# %%
models_c.drop(['ROC AUC','Balanced Accuracy'],axis=1)
# Out:
#                                Accuracy  F1 Score  Time Taken
# Model
# ExtraTreesClassifier               0.98      0.98        0.86
# RandomForestClassifier             0.98      0.98        0.99
# XGBClassifier                      0.98      0.98        4.78
# LGBMClassifier                     0.98      0.98        2.49
# BaggingClassifier                  0.97      0.97        0.45
# DecisionTreeClassifier             0.97      0.97        0.12
# ExtraTreeClassifier                0.96      0.96        0.07
# LogisticRegression                 0.96      0.96        1.05
# SVC                                0.95      0.95        1.61
# LinearDiscriminantAnalysis         0.94      0.94        0.17
# LabelPropagation                   0.93      0.93        4.54
# LabelSpreading                     0.93      0.93        9.23
# NuSVC                              0.92      0.92       11.20
# KNeighborsClassifier               0.92      0.92        1.32
# AdaBoostClassifier                 0.87      0.87        1.64
# LinearSVC                          0.85      0.85        2.94
# CalibratedClassifierCV             0.85      0.85       10.56
# SGDClassifier                      0.84      0.84        0.38
# Perceptron                         0.82      0.81        0.17
# NearestCentroid                    0.77      0.77        0.11
# RidgeClassifier                    0.74      0.73        0.12
# RidgeClassifierCV                  0.74      0.73        0.18
# BernoulliNB                        0.74      0.74        0.13
# PassiveAggressiveClassifier        0.72      0.70        0.18
# GaussianNB                         0.65      0.62        0.08
# QuadraticDiscriminantAnalysis      0.55      0.51        0.15
# DummyClassifier                    0.20      0.20        0.07
